# %% [markdown]
# # 1.Importing the Neccessary Libraries

# %%
# Import important libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2. Reading the dataset(via Pandas)

# %%
#Reading the dataset

House_Price = pd.read_csv(r"D:\Machine Learning Models/train.csv")

# %%
House_Price
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# # 3. Inspecting the dataset

# %%
House_Price.shape # checking the shape of dataset
# Out:
# (1460, 81)

# %%
House_Price.info()  # understanding datatypes and null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
House_Price.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
House_Price.select_dtypes(include='object').columns # to see a particular type of column)
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
House_Price.describe() #Descriptive statistics for columns
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# # 4. Data Preparation ( Cleaning, handling missing values, outliers, Encoding,value_counts, change in format etc.)

# %%
# Check for Null values # Checking for missing values

round(House_Price.isnull().sum() / len(House_Price) * 100,0)     # in terms of percenatge
# Out:
# Id                0.0
# MSSubClass        0.0
# MSZoning          0.0
# LotFrontage      18.0
# LotArea           0.0
#                  ...
# MoSold            0.0
# YrSold            0.0
# SaleType          0.0
# SaleCondition     0.0
# SalePrice         0.0
# Length: 81, dtype: float64

# %%
threshold = 80
missing_percentage = (House_Price.isnull().sum() / len(House_Price)) * 100
variables_above_threshold = missing_percentage[missing_percentage > threshold]

# %%
variables_above_threshold
# Out:
# Alley          93.767123
# PoolQC         99.520548
# Fence          80.753425
# MiscFeature    96.301370
# dtype: float64

# %%
House_Price.drop(['Alley','PoolQC','Fence','MiscFeature','LotFrontage','FireplaceQu'],axis=1,inplace=True)

# %%
House_Price.shape
# Out:
# (1460, 75)

# %%
House_Price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  Neighborhood   1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Condition2     1460 non-null   object
#  13  BldgType       1460 non-null   object
#  14  HouseStyle     1460 non-null   object
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
# ...

# %%
House_Price['SalePrice']
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
House_Price.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0   1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1   2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2   3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3   4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4   5          60       RL    14260   Pave      IR1         Lvl    AllPub
# 5   6          50       RL    14115   Pave      IR1         Lvl    AllPub
# 6   7          20       RL    10084   Pave      Reg         Lvl    AllPub
# 7   8          60       RL    10382   Pave      IR1         Lvl    AllPub
# 8   9          50       RM     6120   Pave      Reg         Lvl    AllPub
# 9  10         190       RL     7420   Pave      Reg         Lvl    AllPub
#
#   LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    Inside       Gtl  ...             0         0           0        0
# ...

# %%
House_Price.loc[:,['LotArea','SalePrice']]
# Out:
#       LotArea  SalePrice
# 0        8450     208500
# 1        9600     181500
# 2       11250     223500
# 3        9550     140000
# 4       14260     250000
# ...       ...        ...
# 1455     7917     175000
# 1456    13175     210000
# 1457     9042     266500
# 1458     9717     142125
# 1459     9937     147500
#
# [1460 rows x 2 columns]

# %% [markdown]
# # 5. EDA or Exploratory Data Analysis ( Visualizations to better understand data)

# %%
# # Plotting a scatter plot to visualize the relationship between Lot Area and Sale Price
sns.scatterplot(x='LotArea',y='SalePrice',data=House_Price)
# Out:
# <Axes: xlabel='LotArea', ylabel='SalePrice'>

# %%
House_Price.Heating.value_counts()
# Out:
# Heating
# GasA     1428
# GasW       18
# Grav        7
# Wall        4
# OthW        2
# Floor       1
# Name: count, dtype: int64

# %%
House_Price.loc[:,['Heating','SalePrice']]
# Out:
#      Heating  SalePrice
# 0       GasA     208500
# 1       GasA     181500
# 2       GasA     223500
# 3       GasA     140000
# 4       GasA     250000
# ...      ...        ...
# 1455    GasA     175000
# 1456    GasA     210000
# 1457    GasA     266500
# 1458    GasA     142125
# 1459    GasA     147500
#
# [1460 rows x 2 columns]

# %%
House_Price.select_dtypes(include='object')
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...      ...         ...       ...       ...       ...
# 1455       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2  ... Electrical KitchenQual  \
# ...

# %%
House_Price1 = House_Price.select_dtypes(exclude='object')

# %%
House_Price1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 37 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   LotArea        1460 non-null   int64
#  3   OverallQual    1460 non-null   int64
#  4   OverallCond    1460 non-null   int64
#  5   YearBuilt      1460 non-null   int64
#  6   YearRemodAdd   1460 non-null   int64
#  7   MasVnrArea     1452 non-null   float64
#  8   BsmtFinSF1     1460 non-null   int64
#  9   BsmtFinSF2     1460 non-null   int64
#  10  BsmtUnfSF      1460 non-null   int64
#  11  TotalBsmtSF    1460 non-null   int64
#  12  1stFlrSF       1460 non-null   int64
#  13  2ndFlrSF       1460 non-null   int64
#  14  LowQualFinSF   1460 non-null   int64
#  15  GrLivArea      1460 non-null   int64
#  16  BsmtFullBath   1460 non-null   int64
#  17  BsmtHalfBath   1460 non-null   int64
# ...

# %%
# Correlation heatmap ( Multivariate analysis : gives understanding of multiple variables involved)
corr = House_Price1.corr()
plt.figure(figsize=(30, 20))
sns.heatmap(corr, annot=True)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
House_Price1 = House_Price[['SalePrice','OverallQual','YearBuilt','GarageCars','GarageArea','GrLivArea','TotalBsmtSF','1stFlrSF','FullBath','TotRmsAbvGrd','YearRemodAdd']]

# %%
House_Price1
# Out:
#       SalePrice  OverallQual  YearBuilt  GarageCars  GarageArea  GrLivArea  \
# 0        208500            7       2003           2         548       1710
# 1        181500            6       1976           2         460       1262
# 2        223500            7       2001           2         608       1786
# 3        140000            7       1915           3         642       1717
# 4        250000            8       2000           3         836       2198
# ...         ...          ...        ...         ...         ...        ...
# 1455     175000            6       1999           2         460       1647
# 1456     210000            6       1978           2         500       2073
# 1457     266500            7       1941           1         252       2340
# 1458     142125            5       1950           1         240       1078
# 1459     147500            5       1965           1         276       1256
#
#       TotalBsmtSF  1stFlrSF  FullBath  TotRmsAbvGrd  YearRemodAdd
# ...

# %%
House_Price1.isnull().sum()
# Out:
# SalePrice       0
# OverallQual     0
# YearBuilt       0
# GarageCars      0
# GarageArea      0
# GrLivArea       0
# TotalBsmtSF     0
# 1stFlrSF        0
# FullBath        0
# TotRmsAbvGrd    0
# YearRemodAdd    0
# dtype: int64

# %% [markdown]
# # 6. Divide components into X and Y and Train Test Split

# %%
from sklearn.model_selection import train_test_split

# Putting feature variable to X
X = House_Price1.drop('SalePrice',axis=1)

# Putting response variable to y
y = House_Price1[['SalePrice']]

# %%
y.head()
# Out:
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000

# %%
X.head(10)
# Out:
#    OverallQual  YearBuilt  GarageCars  GarageArea  GrLivArea  TotalBsmtSF  \
# 0            7       2003           2         548       1710          856
# 1            6       1976           2         460       1262         1262
# 2            7       2001           2         608       1786          920
# 3            7       1915           3         642       1717          756
# 4            8       2000           3         836       2198         1145
# 5            5       1993           2         480       1362          796
# 6            8       2004           2         636       1694         1686
# 7            7       1973           2         484       2090         1107
# 8            7       1931           2         468       1774          952
# 9            5       1939           1         205       1077          991
#
#    1stFlrSF  FullBath  TotRmsAbvGrd  YearRemodAdd
# 0       856         2             8          2003
# 1      1262         2             6          1976
# ...

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.8,test_size=0.2,random_state=100)

# %%
X_train
# Out:
#       OverallQual  YearBuilt  GarageCars  GarageArea  GrLivArea  TotalBsmtSF  \
# 133             8       2001           2         471       1296         1267
# 290             8       2006           2         685       1919         1079
# 24              5       1968           1         270       1060         1060
# 1093            5       1965           2         884       1200          864
# 1288            8       2000           2         499       1659         1501
# ...           ...        ...         ...         ...        ...          ...
# 802             7       2005           2         410       1456          728
# 53              9       1981           3         894       1842         1842
# 350             9       2007           2         617       1869         1869
# 79              5       1910           2         440       1230          440
# 792             7       1996           2         455       2013         1117
#
# ...

# %%
X_test
# Out:
#       OverallQual  YearBuilt  GarageCars  GarageArea  GrLivArea  TotalBsmtSF  \
# 1436            4       1971           2         528        864          864
# 57              7       2004           2         565       1720          860
# 780             7       1995           2         402       1253         1237
# 382             7       2006           2         639       1797          939
# 1170            6       1977           1         358       1118         1096
# ...           ...        ...         ...         ...        ...          ...
# 1328            6       1920           2         520       2792         1510
# 1033            7       2002           3         900       1654         1654
# 977             7       2006           2         569       1241         1241
# 661             8       1994           3         711       2448         1629
# 914             6       2009           2         528       1224          612
#
# ...

# %%
y_train
# Out:
#       SalePrice
# 133      220000
# 290      233230
# 24       154000
# 1093     146000
# 1288     278000
# ...         ...
# 802      189000
# 53       385000
# 350      318061
# 79       110000
# 792      269790
#
# [1168 rows x 1 columns]

# %%
y_test
# Out:
#       SalePrice
# 1436     120500
# 57       196500
# 780      176000
# 382      213500
# 1170     171000
# ...         ...
# 1328     256000
# 1033     230000
# 977      199900
# 661      402000
# 914      173733
#
# [292 rows x 1 columns]

# %% [markdown]
# # 7. Training the Data (with the appropriate alogorithm from the right family alogrithms)

# %%
from sklearn.linear_model import LinearRegression

# %%
#instantiate 

Lr = LinearRegression()

# %%
# Linear Regression Fit

Lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# Make predictions 
y_pred = Lr.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
from sklearn.metrics import mean_squared_error

# %%
# Calculate mean squared error
r2 = r2_score(y_test, y_pred)
print("r2_score:", r2)
# Out:
# r2_score: 0.8138356317529102
